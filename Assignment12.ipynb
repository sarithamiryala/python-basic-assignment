# %% [markdown]
# Q1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
#
# Ans: PdfFileReader() method can be opened in read binary mode 'rb' while opening the pdffile and      PdfFileWriter() method can be opened by passing 'wb' as argument write binary mode
#
#
# Q2. From a PdfFileReader object, how do you get a Page object for page 5?
#
# Ans: pdf1.getPage(5) method can be used to get page 5 of pdf
#
#
#
# Q3. What PdfFileReader variable stores the number of pages in the PDF document?
#
# Ans: pdf.numpages() variable stores the number of pages in the pdf document
#
#
# Q4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do
# before you can obtain Page objects from it?
#
# Ans: pdfwriter.encrypt('swordfish')
#
#
# Q5. What methods do you use to rotate a page?
#
# Ans: rotateClockwise(angle) method rotates the pdf page by given angle
#
#
# Q6. What is the difference between a Run object and a Paragraph object?
#
# Ans:Run object is associated with inline content like text,pictures or anyother items that are flowed between the block-item boundaries within a paragraph
#     paragraph object has runs attributes that are run objects.It contain a plain paragraph with some bold and some italics
#
#
# Q7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?
#
# Ans: a pain text with bold and some italics
#
#
#
# Q8. What type of object has bold, underline, italic, strike, and outline variables?
#
# Ans: Run object has bold,underline, italic strike and outline variables
#
#
# Q9. What is the difference between False, True, and None for the bold variable?
#
# Ans:  False means bold is false (boolean value '0')
#
#       True means bold is true boolean 1
#
#       none means where the field takes option list
#
#
# Q10. How do you create a Document object for a new Word document?
#
# Ans:doc1 = open('document1.docx','rb') # already avaiable document
#
#     doc2 = open(document2.docx','wb') # you can open new document
#
# Q11. How do you add a paragraph with the text'Hello', there!; to a Document object stored in a
# variable named doc?
#
# Ans:import docx
#
#     doc = docx.Document()
#
#     doc.add_paragraph('Hello, world!')
#
#     doc.save('helloworld.docx')
#
#
# Q12. What integers represent the levels of headings available in Word documents?
#
# Ans: doc = docx.Document()
#
#      doc.add_heading('Header 0', 0)
#
#      doc.add_heading('Header 1', 1)
#
#      doc.add_heading('Header 2', 2)
#
#      doc.add_heading('Header 3', 3)
#
#      doc.add_heading('Header 4', 4)
#
#      doc.save('headings.docx')

# %%
import PyPDF2
file1 = open('abc.pdf','rb')
pdf1 = PyPDF2.PdfFileReader(file1)
print(pdf1.numPages)
page0bj = pdf1.getPage(5)
print(page0bj.extractText())
# Out:
# 15
# Symmetry
# 2020
# ,
# 12
# ,1787
# 6of15
# Down-samplingisthemostimportantprocessofextractingfeaturesinanetwork,anditcanextract
# featuredetailswell,whichhasanimportantforsubsequentsegmentationoperations.
# Comparedwiththe3D-UNetconvolutionalneuralnetwork,the3D-Res2UNetconvolutionalneural
# networkchangestheoriginalCBRmoduleinthetwodown-samplings,namelyConv
# +
# BN
# +
# ReLU,
# andreplacesthe3Dbasicconvolutionmodulewiththe3D-Res2Netmoduleasawhole.Therefore,
# themethodofintegratingtheresidualnetworkintotheentirenetworkcanmakethenetworkdeeper,
# andbecauseofthestrongfeatureextractionabilityofthe3D-Res2Netmoduleandthephasedupdate
# oftheconvolutionkernelweightsofeachchannel,theoverallnetworkisabletocaptureverysmall
# features.Withanimprovedperformance,theconnectionmethodwherex_1isdirectlymappedto
# y_1inthemodulee
#
# ectivelyreducesnetworkparametersandtheresourceconsumption.Therefore,
# thenetworkwillnota
#
# ectthenetworkspeedduetoexcessiveredundancy.
# 4.ExperienceandResults
# 4.1.Dataset
# ThismethodisvalidatedonthepublicdatasetofLUNA16[
# 12
# ].Thedatasetcontainsatotalof
# 888setsofCTimageswithatotalof1186lungnodules.Duringtheexperiment,thedatawasrandomly
# dividedintothreeparts,70%ofthedatawasusedfortraining,20%ofthedatawasusedfortesting,
# and10%ofthedatawasusedforThecriterionforjudginganoduleintheLUNA16
# datasetisthatatleastthreeofthefourradiologistsdeterminethattheradiusofthenoduleisgreater
# than3mm.Therefore,intheannotationsofthedataset,non-nodules,noduleswitharadiuslessthan
# 3mm,andnoduleswitharadiusgreaterthan3mmareconsideredbyoneortworadiologistsas
# unrelated
# 4.2.DataPreprocessing
# 4.2.1.DataFormatConversion
# Inthedataset,eachchestCTsamplemainlycontainstwoparts:(1)TherawdataofchestCT,
# includingtwowiththesu
#
# xzrawandmhd.ThezrawsavestheoriginalCTdataandthemhd
# savestheheaderinformationoftheCTdata.Themostimportantinformationisestablishingan
# axisoriginandpixelspacing.TheoriginrepresentsthecoordinatesoftheoriginoftheCTdatain
# theworldcoordinatesystem,whilethespacingsubdividestheCTdatatoalengthofapixelinthe
# worldcoordinates.(2)ACSV(CommaSeparatedValues)withnoduleannotationinformation.
# ThecontentoftheisshowninTable
# 1
# .
# Table1.
# LabelinginformationofpulmonarynodulesinaCSV
# SeriesuidCoordXCoordYCoordZDiameter(mm)
# LKDS-00539
#
# 70.7218023
#
# 87.588631936.59.4028638
# LKDS-00540
#
# 50.2048319
#
# 90.032470150.57.9106295
# SincetheCTdataareexpressedinanaturalcoordinatesystem,theworldcoordinatesofthelung
# nodulesneedtobeconvertedtothenaturalcoordinatesoftheCTvoxelstocorrespondtotheCTdata
# beforetheactualoperation.Theconversionformulasareasfollows:
# voxelcoord
# =
# (
# coord
#
# origin
# )
# spacing
# (2)
# voxeldiam
# =
# daimeter
# _
# mm
# spacing
# (3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5952/2639386623.py in <module>
#       6 print(page0bj.extractText())
#       7
# ----> 8 pdf2 = PyPDF2.PdfFileWriter(file1)
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
pdf2 = PyPDF2.PdfFileWriter()
pdf2.encrypt('swordfish')

# %%
import docx
d = open('abcd.docx','wb')
d.writelines(helloworld /)
# Out:
#   File "C:\Users\SAMARTH\AppData\Local\Temp/ipykernel_5952/532356490.py", line 3
#     d.writelines(helloworld /)
#                              ^
# SyntaxError: invalid syntax

# %%
import docx
doc = docx.Document()
doc.add_paragraph('Hello, world!')

doc.save('helloworld.docx')

# %%
doc = docx.Document()
doc.add_heading('Header 0', 0)
doc.add_heading('Header 1', 1)
doc.add_heading('Header 2', 2)
doc.add_heading('Header 3', 3)
doc.add_heading('Header 4', 4)
doc.save('headings.docx')
